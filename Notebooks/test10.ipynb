# %%
#<INSERT YOUR COS CREDENTIALS, AS EXPLAINED ABOVE>
# RAANON
cos_credentials_prod_ki = {
  'iam_url':'https://iam.ng.bluemix.net/oidc/token',
  'api_key':'0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ',
  'resource_instance_id':'crn:v1:bluemix:public:cloud-object-storage:global:a/db0d062d2b4c0836e18618a5222d8068:22e3b946-6154-4032-8e8f-7cfb0b429602::',
     'url':'https://s3-api.us-geo.objectstorage.service.networklayer.com',
"endpoint":"https://s3-api.us-geo.objectstorage.softlayer.net",
}
cod_credentials_prod_ki2 = {
  "apikey": "2SozF9MkHGQULJZHZTiZOnidaLSc3zIqr3SkDUC0YD0t",
  "endpoints": "https://cos-service.bluemix.net/endpoints",
  "iam_apikey_description": "Auto generated apikey during resource-key operation for Instance - crn:v1:bluemix:public:cloud-object-storage:global:a/db0d062d2b4c0836e18618a5222d8068:22e3b946-6154-4032-8e8f-7cfb0b429602::",
  "iam_apikey_name": "auto-generated-apikey-d7f66b84-8aee-41fa-afbf-b74e33124126",
  "iam_role_crn": "crn:v1:bluemix:public:iam::::serviceRole:Manager",
  "iam_serviceid_crn": "crn:v1:bluemix:public:iam-identity::a/db0d062d2b4c0836e18618a5222d8068::serviceid:ServiceId-4a452452-14c8-428a-b1c2-aa910d8f9244",
  "resource_instance_id": "crn:v1:bluemix:public:cloud-object-storage:global:a/db0d062d2b4c0836e18618a5222d8068:22e3b946-6154-4032-8e8f-7cfb0b429602::"
}
cos_credentials = {  
  'iam_url': cod_credentials_prod_ki2['apikey'],
  'api_key': cod_credentials_prod_ki2['apikey'],  
  'resource_instance_id': cod_credentials_prod_ki2['apikey'],  
  'url': cod_credentials_prod_ki2['apikey'],  

  'endpoint':'https://' + cod_credentials_prod_ki2['apikey'],  
}
cos_credentials_stage1_wd = {
  'iam_url':'https://iam.stage1.ng.bluemix.net/oidc/token',
  'api_key':'xhjheSC7AhSLtvapSDnbyFn17uWUqW5ccAOuHhQxnnEY',
  'resource_instance_id':'crn:v1:staging:public:cloud-object-storage:global:a/68a66698d275aeb48097f868957ab2ed:bbb5aa36-5525-4000-b129-bcb780195098::',
  'url':'https://s3-api.us-geo.objectstorage.uat.service.networklayer.com',
    'endpoint':'https://s3.us-west.objectstorage.uat.softlayer.net'
}
#    'endpoint':'https://cos-service.stage1.ng.bluemix.net/endpoints'
#    'endpoint':'https://s3.us-west.objectstorage.uat.softlayer.net'
#s3.us-west.objectstorage.uat.softlayer.net     s3-api.us-geo.objectstorage.uat.service.networklayer.com

# @hidden_cell
credentials_1 = {
  'iam_url':'https://iam.ng.bluemix.net/oidc/token',
  'api_key':'0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ',
  'resource_instance_id':'crn:v1:bluemix:public:cloud-object-storage:global:a/db0d062d2b4c0836e18618a5222d8068:22e3b946-6154-4032-8e8f-7cfb0b429602::',
  'url':'https://s3-api.us-geo.objectstorage.service.networklayer.com'
}
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_2 = {
    'IBM_API_KEY_ID': 'KFwmHTp1Qbyhr8p3FPUK8tfzw2DouD6X9IFYAxhqUvD9',
    'IBM_SERIVCE_INSTANCE_ID': 'iam-ServiceId-9a91f062-3319-4553-ae5d-7e80afa896ad',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.ng.bluemix.net/oidc/token',
    'BUCKET': 'streams71aa690a314849ce9b242fd1022a028e',
    'FILE': 'pyLDAvis_2.png'
}
cos_credentials_prod_ki = {
  'iam_url':'https://iam.ng.bluemix.net/oidc/token',
  'api_key':'0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ',
  'resource_instance_id':'crn:v1:bluemix:public:cloud-object-storage:global:a/db0d062d2b4c0836e18618a5222d8068:22e3b946-6154-4032-8e8f-7cfb0b429602::',
     'url':'https://s3-api.us-geo.objectstorage.service.networklayer.com',
"endpoint":"https://s3-api.us-geo.objectstorage.softlayer.net",
}
cos_credentials = {
  'iam_url': credentials_2['IBM_AUTH_ENDPOINT'],
  'api_key': credentials_2['IBM_API_KEY_ID'],
  'resource_instance_id': 'NA',
  'url': 'NA',
    'BUCKET': 'streams71aa690a314849ce9b242fd1022a028e',
    'FILE': 'pyLDAvis_2.png',
    
  'endpoint': credentials_2['ENDPOINT']
}

# %%
# Copied from service credentials
credentials_1 = {
  "apikey": "2SozF9MkHGQULJZHZTiZOnidaLSc3zIqr3SkDUC0YD0t",
  "endpoints": "https://cos-service.bluemix.net/endpoints",
  "iam_apikey_description": "Auto generated apikey during resource-key operation for Instance - crn:v1:bluemix:public:cloud-object-storage:global:a/db0d062d2b4c0836e18618a5222d8068:22e3b946-6154-4032-8e8f-7cfb0b429602::",
  "iam_apikey_name": "auto-generated-apikey-d7f66b84-8aee-41fa-afbf-b74e33124126",
  "iam_role_crn": "crn:v1:bluemix:public:iam::::serviceRole:Manager",
  "iam_serviceid_crn": "crn:v1:bluemix:public:iam-identity::a/db0d062d2b4c0836e18618a5222d8068::serviceid:ServiceId-4a452452-14c8-428a-b1c2-aa910d8f9244",
  "resource_instance_id": "crn:v1:bluemix:public:cloud-object-storage:global:a/db0d062d2b4c0836e18618a5222d8068:22e3b946-6154-4032-8e8f-7cfb0b429602::"
}
# copied from Files
credentials_2 = {
    'IBM_API_KEY_ID': 'KFwmHTp1Qbyhr8p3FPUK8tfzw2DouD6X9IFYAxhqUvD9',
    'IBM_SERIVCE_INSTANCE_ID': 'iam-ServiceId-9a91f062-3319-4553-ae5d-7e80afa896ad',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.ng.bluemix.net/oidc/token',
    'BUCKET': 'streams71aa690a314849ce9b242fd1022a028e',
    'FILE': 'pyLDAvis_2.png'
}
# copied from Connections
credentials_3 = {
  'iam_url':'https://iam.ng.bluemix.net/oidc/token',
  'api_key':'0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ',
  'resource_instance_id':'crn:v1:bluemix:public:cloud-object-storage:global:a/db0d062d2b4c0836e18618a5222d8068:22e3b946-6154-4032-8e8f-7cfb0b429602::',
  'url':'https://s3-api.us-geo.objectstorage.service.networklayer.com'
}

save_to_cos({'api_key':'0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ'}, 'streams71aa690a314849ce9b242fd1022a028e', 'test.txt', "this is a test")
#save_to_cos(credentials_1, 'streams71aa690a314849ce9b242fd1022a028e', 'test.txt', "this is a test")
#save_to_cos(credentials_3, 'streams71aa690a314849ce9b242fd1022a028e', 'test.txt', "this is a test")
#save_to_cos(credentials_2, 'streams71aa690a314849ce9b242fd1022a028e', 'test.txt', "this is a test")
text = read_from_cos(credentials_2, None, 'test.txt')
print(text)
# Out:
# Saving streams71aa690a314849ce9b242fd1022a028e/test.txt ( 14 bytes)
# Reading streams71aa690a314849ce9b242fd1022a028e/test.txt
# b'this is a test'

# %%
def save_to_cos( cred, bucket_name, object_name, data):
    """
    'cred' may have various key-values, depending on where the credentials where copied from.
    """
    import requests

    default_iam_url = 'https://iam.ng.bluemix.net/oidc/token'
    default_endpoint = 'https://s3-api.us-geo.objectstorage.service.networklayer.com'
    # Check for credentials or arguments. Any StopIteration error means that no key/value was defined.
    api_key = next((n for n in [cred.get('apikey'), cred.get('api_key'), cred.get('IBM_API_KEY_ID')] if n is not None))
    iam_url = next((n for n in [cred.get('iam_url'), cred.get('IBM_AUTH_ENDPOINT')] if n is not None), default_iam_url)
    endpoint = next((n for n in [cred.get('url'), cred.get('ENDPOINT')] if n is not None), default_endpoint)

    full_object_path = bucket_name + "/" + object_name
    print("Saving", full_object_path, "(", str(len(data)), "bytes)")

    response = requests.post(
                url = iam_url,
                headers = {"Content-Type": "application/x-www-form-urlencoded"},
                params = {"grant_type":"urn:ibm:params:oauth:grant-type:apikey","apikey":api_key},
                verify = True)
    if str(response) != "<Response [200]>":
        print( "ERROR: POST Response =", response)
        return
    bearer_token = response.json()["access_token"]
    
    response = requests.put(
                url = endpoint + "/" + full_object_path,
                headers = {"Authorization": "bearer " + bearer_token},
                data = data)    
    if str(response) != "<Response [200]>":
        print( "ERROR: PUT Response =", response)

# %%
def read_from_cos(cred, bucket_name, object_name):
    """
    'cred' may have various key-values, depending on where the credentials where copied from.
    """
    import requests

    default_iam_url = 'https://iam.ng.bluemix.net/oidc/token'
    default_endpoint = 'https://s3-api.us-geo.objectstorage.service.networklayer.com'
    # Check for credentials or arguments. Any StopIteration error means that no key/value was defined.
    api_key = next((n for n in [cred.get('apikey'), cred.get('api_key'), cred.get('IBM_API_KEY_ID')] if n is not None))
    iam_url = next((n for n in [cred.get('iam_url'), cred.get('IBM_AUTH_ENDPOINT')] if n is not None), default_iam_url)
    endpoint = next((n for n in [cred.get('url'), cred.get('ENDPOINT')] if n is not None), default_endpoint)

    full_object_path = bucket_name + "/" + object_name
    print("Reading", full_object_path)

    response = requests.post(
                url = iam_url,
                headers = {"Content-Type": "application/x-www-form-urlencoded"},
                params = {"grant_type":"urn:ibm:params:oauth:grant-type:apikey","apikey":api_key},
                verify = True)
    if str(response) != "<Response [200]>":
        print( "ERROR: POST Response =", response)
        return
    bearer_token = response.json()["access_token"]

    response=requests.get(
                url = endpoint + "/" + full_object_path,
                headers = {"Authorization": "bearer " + bearer_token},
                params=None,
                verify=True)
    if str(response) != "<Response [200]>":
        print( "ERROR: PUT Response =", response)
 
    return response.content

# %%
dict1 = { 'a': 1}

#print( next(filter(lambda n: n is not None, [dict1.get('z'), dict1.get('az')]), 'default'))
#y = next((n for n in [dict1.get('z'), dict1.get('a')] if n is not None), 'All are Nones')
y = next((n for n in [dict1.get('z'), dict1.get('az')] if n is not None))
print(y)
# Out:
# StopIterationTraceback (most recent call last)
# <ipython-input-26-ce069497fcf2> in <module>()
#       3 #print( next(filter(lambda n: n is not None, [dict1.get('z'), dict1.get('az')]), 'default'))
#       4 #y = next((n for n in [dict1.get('z'), dict1.get('a')] if n is not None), 'All are Nones')
# ----> 5 y = next((n for n in [dict1.get('z'), dict1.get('az')] if n is not None))
#       6 print(y)
#
# StopIteration:

# %% [markdown]
# https://datascience.ibm.com/docs/content/analyze-data/load-and-access-data.html?context=analytics
# Connection details
# Login URL*
# https://s3-api.us-geo.objectstorage.softlayer.net
#
# Resource Instance ID*
# crn:v1:bluemix:public:cloud-object-storage:global:a/db0d062d2b4c0836e18618a5222d8068:22e3b946-6154-4032-8e8f-7cfb0b429602::
#
# API Key*

# %%
import sys
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_22e3b946615440328e8f7cfb0b429602 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='KFwmHTp1Qbyhr8p3FPUK8tfzw2DouD6X9IFYAxhqUvD9',
    ibm_service_instance_id="iam-ServiceId-9a91f062-3319-4553-ae5d-7e80afa896ad",
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about your possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/
streaming_body_1 = client_22e3b946615440328e8f7cfb0b429602.get_object(Bucket='streams71aa690a314849ce9b242fd1022a028e', Key='pyLDAvis_2.png')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(streaming_body_1, "__iter__"): streaming_body_1.__iter__ = types.MethodType( __iter__, streaming_body_1 ) 

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about your possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/
streaming_body_2 = client_22e3b946615440328e8f7cfb0b429602.get_object(Bucket='streams71aa690a314849ce9b242fd1022a028e', Key='LDA_Topic_Classification.stp')['Body']
# add missing __iter__ method so pandas accepts body as file-like object
if not hasattr(streaming_body_2, "__iter__"): streaming_body_2.__iter__ = types.MethodType( __iter__, streaming_body_2 )

# %% [markdown]
# <a id="setup2DELETE"></a>
# ### 1.2 DELETE [Provide Credentials for Cloud Object Storage (COS)](#TOC)
# The COS credentials will be used at the end of this tutorial for storing the created model.
#
# In order to insert your credentials into the notebook, open the `Connections` tab to the right.
# * Use the notebook menu bar to open the `Data` panel on the right.
# * Select the `Connections` tab.
# ***
# * Click in the empty cell below and select <font color=blue>__insert to code__</font> for your __Cloud Object Storage__ service.
# * <font color=red>Change the *name*</font> of the COS credentials variable to __cos_credentials__.
# * The dictionary variable should contain the following keys: *iam_url, api_key, resource_instance_id, and url*.
# * Add an <font color=red>*additional key*</font> to the variable called __endpoint__.
#    * Get the the endpoint value from your Cload Object Storage (COS) service's page.
#       * From your Bluemix [Dashboard](https://console.bluemix.net/dashboard/apps), select the COS service.
#       * Select `Endpoint` from the menu on the left.
#       * Choose the __PUBLIC__ endpoint for your *location* (for example, *us-geo*).
#       * Prefix the endpoint value with "https://"
#
# Your variable should look like this...
# ```
# cos_credentials = {
#   'iam_url':'<YOUR-VALUE>',
#   'api_key':'<YOUR-VALUE>',
#   'resource_instance_id':'<YOUR-VALUE>',
#   'url':'<YOUR-VALUE>',
#
#   'endpoint':'https://<YOUR-VALUE>'
# }
# ```

# %% [markdown]
# <a id="setup2"></a>
# ### 1.2 [Provide Credentials for Cloud Object Storage (COS)](#TOC)
# The COS credentials will be used at the end of this tutorial for storing the created model.
#
# There are various methods for getting your credentials:
# * From the `Connections` tab (on right of notebook when the `Data`attchmt panel is opened), select <font color=blue>__Insert to code__</font>.
# * From the `Files` tab (on right), select <font color=blue>__Insert to code__</font>-><font color=blue>__Insert Credentials__</font> from one of your files.
# * From the __Bluemix Cloud Object Storage__ `Service credentials` page, open <font color=blue>__View credentials__</font> and <font color=blue>copy</font>.
#
# At minimum, the credentials variable should contain an <font color=blue>api key</font> (*api_key, apikey* or *IBM_API_KEY_ID*). (The provided functions have defaults for other required access values, but you might want to verify that they are appropriate for your environment.)
# <font color=red>Change the *name*</font> of the credentials variable to __cos_credentials__.

# %% [markdown]
# <a id="setup3"></a>
# ### 1.3 [Provide COS bucket and object names](#TOC)
# Choose a COS bucket name and object names for your packaged model (.gz) and topic-terms (.csv) files.
# <font color=red>Be sure that the bucket already exists!</font>
# you can find your project's default bucket name from:
# * Files tab
# * Project Settings tab
# (advantage of default bucket is that files can be viewed from DSX project Data->Files)

# %%
data = []
data.append( {'text': 'aa1 aa2 aa3', 'newsgroup': 'a'})
data.append( {'text': 'bb1 bb2 bb3', 'newsgroup': 'b'})

# %%
for d in data:
    print(d['text'])
    for w in d['text'].split():
        print("  ", w)
words = [[word for word in text.split()] for text in data[0]]
words
# Out:
# aa1 aa2 aa3
#    aa1
#    aa2
#    aa3
# bb1 bb2 bb3
#    bb1
#    bb2
#    bb3
# [['text'], ['newsgroup']]

# %%
# PYTHON 2 ONLY !!!
#!rm -fr /tmp/sca9-7277eb31bca08b-bc196c953de3/pip-build/mqlight
# !pip install --user mqlight

# %%
import mqlight,time

service = "https://mqlight-lookup-prod01.messagehub.services.us-south.bluemix.net/Lookup?serviceId=3ba03d3f-158f-4016-9355-9447feb29a06"
mhuser = "rTSI8Xh9Vsqy7yfg"
mhpassword = "pCZ29WszfOmpdYWG68Zfc7rJ1pflG2nJ"

security_options = {
      'user': str(mhuser),
      'password': str(mhpassword)
}

def on_message(message_type, data, delivery):
    print(data)
def on_started(err):
    client.subscribe('newsData', on_message=on_message)

client = mqlight.Client(service=service,security_options=security_options,on_started=on_started)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-3-92393ae32e94> in <module>()
#      15     client.subscribe('newsData', on_message=on_message)
#      16
# ---> 17 client = mqlight.Client(service=service,security_options=security_options,on_started=on_started)
#
# /gpfs/fs01/user/sca9-7277eb31bca08b-bc196c953de3/.local/lib/python2.7/site-packages/mqlight/mqlight.pyc in __init__(self, service, client_id, security_options, on_started, on_state_changed)
#     699                 if on_started:
#     700                     on_started(err)
# --> 701             self._perform_connect(connect_callback, service, True)
#     702         LOG.exit('Client.constructor', self._id, None)
#     703
#
# /gpfs/fs01/user/sca9-7277eb31bca08b-bc196c953de3/.local/lib/python2.7/site-packages/mqlight/mqlight.pyc in _perform_connect(self, on_started, service, new_client)
#     809                     self._id,
#     810                     None)
# ...

# %%
def save_to_cos( cred, bucket_name, object_name, data):
    import requests

    default_iam_url = 'https://iam.ng.bluemix.net/oidc/token'
    default_endpoint = 'https://s3-api.us-geo.objectstorage.service.networklayer.com'
    # Check for credentials or arguments. A StopIteration error means that a valid key was not found.
    api_key = next((n for n in [cred.get('apikey'), cred.get('api_key'), cred.get('IBM_API_KEY_ID')] if n is not None))
    iam_url = next((n for n in [cred.get('iam_url'), cred.get('IBM_AUTH_ENDPOINT')] if n is not None), default_iam_url)
    endpoint = next((n for n in [cred.get('url'), cred.get('ENDPOINT')] if n is not None), default_endpoint)
    
    full_object_path = bucket_name + "/" + object_name
    print("Saving", full_object_path, "(", str(len(data)), "bytes)")

    response = requests.post(
                url = iam_url,
                headers = {"Content-Type": "application/x-www-form-urlencoded"},
                params = {"grant_type":"urn:ibm:params:oauth:grant-type:apikey","apikey":api_key},
                verify = True)
    if response.status_code != 200:
        print( "ERROR: POST Response =", response.status_code, response.reason, response.text)
        return
    bearer_token = response.json()["access_token"]
    
    response = requests.put(
                url = endpoint + "/" + full_object_path,
                headers = {"Authorization": "bearer " + bearer_token},
                data = data)    
    if response.status_code != 200:
        print( "ERROR: PUT Response =", response.status_code, response.reason, response.text)

# %%
#save_to_cos({'api_key':'0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ'}, 'streams71aa690a314849ce9b242fd1022a028e', 'test.txt', "this is a test")
#save_to_cos({'api_key':'0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ', 'iam_url':'https://iam.ng.bluemix.net/oidc/token'}, 'pyml', 'test.txt', "this is a test")
save_to_cos({'api_key':'0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ'}, 'pyml', 'test.txt', "this is a test")
# Out:
# Saving pyml/test.txt ( 14 bytes)

# %%
# 8x
mh_credentials = {
  "mqlight_lookup_url": "https://mqlight-lookup-prod01.messagehub.services.us-south.bluemix.net/Lookup?serviceId=3ba03d3f-158f-4016-9355-9447feb29a06",
  "api_key": "rTSI8Xh9Vsqy7yfgpCZ29WszfOmpdYWG68Zfc7rJ1pflG2nJ",
  "kafka_admin_url": "https://kafka-admin-prod01.messagehub.services.us-south.bluemix.net:443",
  "kafka_rest_url": "https://kafka-rest-prod01.messagehub.services.us-south.bluemix.net:443",
  "kafka_brokers_sasl": [
    "kafka04-prod01.messagehub.services.us-south.bluemix.net:9093",
    "kafka02-prod01.messagehub.services.us-south.bluemix.net:9093",
    "kafka01-prod01.messagehub.services.us-south.bluemix.net:9093",
    "kafka01-prod01.messagehub.services.us-south.bluemix.net:9093",
    "kafka03-prod01.messagehub.services.us-south.bluemix.net:9093"
  ],
  "user": "rTSI8Xh9Vsqy7yfg",
  "password": "pCZ29WszfOmpdYWG68Zfc7rJ1pflG2nJ"
}
mh_credentials = {
  "instance_id": "3ba03d3f-158f-4016-9355-9447feb29a06",
  "mqlight_lookup_url": "https://mqlight-lookup-prod01.messagehub.services.us-south.bluemix.net/Lookup?serviceId=3ba03d3f-158f-4016-9355-9447feb29a06",
  "api_key": "Azrmak5KqB5aQ9YghzWI1bhxfxqB0ki7qXID3OlXOHPm54NX",
  "kafka_admin_url": "https://kafka-admin-prod01.messagehub.services.us-south.bluemix.net:443",
  "kafka_rest_url": "https://kafka-rest-prod01.messagehub.services.us-south.bluemix.net:443",
  "kafka_brokers_sasl": [
    "kafka01-prod01.messagehub.services.us-south.bluemix.net:9093",
    "kafka05-prod01.messagehub.services.us-south.bluemix.net:9093",
    "kafka03-prod01.messagehub.services.us-south.bluemix.net:9093",
    "kafka02-prod01.messagehub.services.us-south.bluemix.net:9093",
    "kafka04-prod01.messagehub.services.us-south.bluemix.net:9093"
  ],
  "user": "Azrmak5KqB5aQ9Yg",
  "password": "hzWI1bhxfxqB0ki7qXID3OlXOHPm54NX"
}
# stage1
mh_credentials = {
  "instance_id": "86ce5bfa-268e-4786-a7e9-91f8427f2e17",
  "mqlight_lookup_url": "https://mqlight-lookup-stage1.messagehub.services.us-south.bluemix.net/Lookup?serviceId=86ce5bfa-268e-4786-a7e9-91f8427f2e17",
  "api_key": "CBa3cYnfW1iWM25LNewJVZaxEP1qjKlThEeqz2Zrnkzu7VXd",
  "kafka_admin_url": "https://kafka-admin-stage1.messagehub.services.us-south.bluemix.net:443",
  "kafka_rest_url": "https://kafka-rest-stage1.messagehub.services.us-south.bluemix.net:443",
  "kafka_brokers_sasl": [
    "kafka02-stage1.messagehub.services.us-south.bluemix.net:9093",
    "kafka04-stage1.messagehub.services.us-south.bluemix.net:9093",
    "kafka01-stage1.messagehub.services.us-south.bluemix.net:9093",
    "kafka03-stage1.messagehub.services.us-south.bluemix.net:9093",
    "kafka05-stage1.messagehub.services.us-south.bluemix.net:9093"
  ],
  "user": "CBa3cYnfW1iWM25L",
  "password": "NewJVZaxEP1qjKlThEeqz2Zrnkzu7VXd"
}
#mh_topic = "testTopic1"

# m9
mh_credentials = {
  "instance_id": "b32d208f-fbdb-425c-95d3-5b00b56209c4",
  "mqlight_lookup_url": "https://mqlight-lookup-prod02.messagehub.services.us-south.bluemix.net/Lookup?serviceId=b32d208f-fbdb-425c-95d3-5b00b56209c4",
  "api_key": "u4cbPZKOoOHI9uZ5J66JaZBtOF2cRVPYu4UEAG7PXIn4SleB",
  "kafka_admin_url": "https://kafka-admin-prod02.messagehub.services.us-south.bluemix.net:443",
  "kafka_rest_url": "https://kafka-rest-prod02.messagehub.services.us-south.bluemix.net:443",
  "kafka_brokers_sasl": [
    "kafka01-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka03-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka04-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka02-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka05-prod02.messagehub.services.us-south.bluemix.net:9093"
  ],
  "user": "u4cbPZKOoOHI9uZ5",
  "password": "J66JaZBtOF2cRVPYu4UEAG7PXIn4SleB"
}

# %%
# m9
mh_credentials = {
  "instance_id": "b32d208f-fbdb-425c-95d3-5b00b56209c4",
  "mqlight_lookup_url": "https://mqlight-lookup-prod02.messagehub.services.us-south.bluemix.net/Lookup?serviceId=b32d208f-fbdb-425c-95d3-5b00b56209c4",
  "api_key": "u4cbPZKOoOHI9uZ5J66JaZBtOF2cRVPYu4UEAG7PXIn4SleB",
  "kafka_admin_url": "https://kafka-admin-prod02.messagehub.services.us-south.bluemix.net:443",
  "kafka_rest_url": "https://kafka-rest-prod02.messagehub.services.us-south.bluemix.net:443",
  "kafka_brokers_sasl": [
    "kafka01-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka03-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka04-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka02-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka05-prod02.messagehub.services.us-south.bluemix.net:9093"
  ],
  "user": "u4cbPZKOoOHI9uZ5",
  "password": "J66JaZBtOF2cRVPYu4UEAG7PXIn4SleB"
}
mh_topic = "newsData"
def create_messagehub_consumer(cred, topic, value_deserializer=lambda v: json.loads(v).encode('utf-8')):
    import ssl
    from kafka import KafkaConsumer
    from kafka.errors import KafkaError

    # Check for credentials or arguments. A StopIteration error means that a valid key was not found.
    username = next((n for n in [cred.get('username'), cred.get('user')] if n is not None))
    password = cred.get('password')
    # Variables from credentials, but with defaults
    security_protocol = cred.get('security_protocol', 'SASL_SSL')
    sasl_mechanism = cred.get('sasl_mechanism', 'PLAIN')
    kafka_brokers_sasl = cred.get('kafka_brokers_sasl', [
        "kafka01-prod01.messagehub.services.us-south.bluemix.net:9093",
        "kafka02-prod01.messagehub.services.us-south.bluemix.net:9093",
        "kafka03-prod01.messagehub.services.us-south.bluemix.net:9093",
        "kafka04-prod01.messagehub.services.us-south.bluemix.net:9093",
        "kafka05-prod01.messagehub.services.us-south.bluemix.net:9093"
    ])

    # Create a new context using system defaults, disable all but TLS1.2
    context = ssl.create_default_context()
    context.options &= ssl.OP_NO_TLSv1
    context.options &= ssl.OP_NO_TLSv1_1

#    consumer = KafkaConsumer(topic,
#                             bootstrap_servers = ('kafka01-prod01.messagehub.services.us-south.bluemix.net:9093,kafka03-prod01.messagehub.services.us-south.bluemix.net:9093,kafka05-prod01.messagehub.services.us-south.bluemix.net:9093,kafka02-prod01.messagehub.services.us-south.bluemix.net:9092,kafka04-prod01.messagehub.services.us-south.bluemix.net:9092'),
#                             sasl_plain_username = ('u4cbPZKOoOHI9uZ5'),
#                             sasl_plain_password = ('J66JaZBtOF2cRVPYu4UEAG7PXIn4SleB'),
#                             security_protocol = ('SASL_SSL'),
#                             ssl_context = context,
#                             sasl_mechanism = ('PLAIN'))
##                             api_version=(0,10))
    consumer = KafkaConsumer( topic,
                             bootstrap_servers = kafka_brokers_sasl,
                             sasl_plain_username = username,
                             sasl_plain_password = password,
                             security_protocol = security_protocol,
                             ssl_context = context,
                             sasl_mechanism = sasl_mechanism)
#                             api_version=(0,10))
#                             value_deserializer=value_deserializer)

    return consumer

mh_consumer = create_messagehub_consumer( mh_credentials, mh_topic)
#mh_consumer.subscribe(mh_topic)

# %%
for msg in mh_consumer:
    print(":",json.dumps(msg))
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-29-968509ef7b52> in <module>()
# ----> 1 for msg in mh_consumer:
#       2     print(":",json.dumps(msg))
#
# /gpfs/fs01/user/sca9-7277eb31bca08b-bc196c953de3/.local/lib/python3.5/site-packages/kafka/consumer/group.py in __next__(self)
#    1073         self._set_consumer_timeout()
#    1074         try:
# -> 1075             return next(self._iterator)
#    1076         except StopIteration:
#    1077             self._iterator = None
#
# /gpfs/fs01/user/sca9-7277eb31bca08b-bc196c953de3/.local/lib/python3.5/site-packages/kafka/consumer/group.py in _message_generator(self)
#    1011             if not self._fetcher.in_flight_fetches():
#    1012                 poll_ms = 0
# -> 1013             self._client.poll(timeout_ms=poll_ms)
#    1014
#    1015             # We need to make sure we at least keep up with scheduled tasks,
#
# ...

# %%
for n,msg in enumerate(mh_consumer):
    #if n == 10: break
    print(n, json.dumps(msg))
print(n)

# %%
n=0
for message in mh_consumer:
#    n = n + 1
#    if n == 10:
#        break
    # message value and key are raw bytes -- decode if necessary!
    # e.g., for unicode: `message.value.decode('utf-8')`
    print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                          message.offset, message.key,
                                          message.value))

# %% [markdown]
# ---

# %%
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_1 = {
    'IBM_API_KEY_ID': 'KFwmHTp1Qbyhr8p3FPUK8tfzw2DouD6X9IFYAxhqUvD9',
    'IBM_SERIVCE_INSTANCE_ID': 'iam-ServiceId-9a91f062-3319-4553-ae5d-7e80afa896ad',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.ng.bluemix.net/oidc/token',
    'BUCKET': 'streams71aa690a314849ce9b242fd1022a028e',
    'FILE': 'test.txt'
}
# @hidden_cell
credentials_2 = {
  'iam_url':'https://iam.ng.bluemix.net/oidc/token',
  'api_key':'0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ',
  'resource_instance_id':'crn:v1:bluemix:public:cloud-object-storage:global:a/db0d062d2b4c0836e18618a5222d8068:22e3b946-6154-4032-8e8f-7cfb0b429602::',
  'url':'https://s3-api.us-geo.objectstorage.service.networklayer.com'
}



import sys
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_22e3b946615440328e8f7cfb0b429602 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='KFwmHTp1Qbyhr8p3FPUK8tfzw2DouD6X9IFYAxhqUvD9',
    ibm_service_instance_id="iam-ServiceId-9a91f062-3319-4553-ae5d-7e80afa896ad",
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about your possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/
streaming_body_1 = client_22e3b946615440328e8f7cfb0b429602.get_object(Bucket='streams71aa690a314849ce9b242fd1022a028e', Key='test.txt')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(streaming_body_1, "__iter__"): streaming_body_1.__iter__ = types.MethodType( __iter__, streaming_body_1 ) 




import ibmos2spark

# @hidden_cell
credentials = {
    'endpoint': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'api_key': 'KFwmHTp1Qbyhr8p3FPUK8tfzw2DouD6X9IFYAxhqUvD9',
    'service_id': 'iam-ServiceId-9a91f062-3319-4553-ae5d-7e80afa896ad',
    'iam_service_endpoint': 'https://iam.ng.bluemix.net/oidc/token'}
credentials = {
    'endpoint': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'api_key': '0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ',
    'service_id': '22e3b946-6154-4032-8e8f-7cfb0b429602',
    'iam_service_endpoint': 'https://iam.ng.bluemix.net/oidc/token'}

configuration_name = 'os_22e3b946615440328e8f7cfb0b429602_configs'
cos = ibmos2spark.CloudObjectStorage(sc, credentials, configuration_name, 'bluemix_cos')

from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
# Please read the documentation of PySpark to learn more about the possibilities to load data files.
# PySpark documentation: https://spark.apache.org/docs/2.0.1/api/python/pyspark.sql.html#pyspark.sql.SparkSession
# The SparkSession object is already initialized for you.
# The following variable contains the path to your file on your IBM Cloud Object Storage.
path_1 = cos.url('test.txt', 'streams71aa690a314849ce9b242fd1022a028e')
print(path_1)

path_1 = cos.url('LDA_Topic_Classification.stp', 'streams71aa690a314849ce9b242fd1022a028e')
example1_df = sqlContext.read.json(path_1)
print(example1_df.printSchema())
#example1_df.take(2)

# %%
mh_credentials = {
  "instance_id": "b32d208f-fbdb-425c-95d3-5b00b56209c4",
  "mqlight_lookup_url": "https://mqlight-lookup-prod02.messagehub.services.us-south.bluemix.net/Lookup?serviceId=b32d208f-fbdb-425c-95d3-5b00b56209c4",
  "api_key": "xHOhyt5OMK0TfmBKOi8AlONgPGlzuR35IwLC6x2NzBdX88qs",
  "kafka_admin_url": "https://kafka-admin-prod02.messagehub.services.us-south.bluemix.net:443",
  "kafka_rest_url": "https://kafka-rest-prod02.messagehub.services.us-south.bluemix.net:443",
  "kafka_brokers_sasl": [
    "kafka04-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka03-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka01-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka02-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka05-prod02.messagehub.services.us-south.bluemix.net:9093"
  ],
  "user": "xHOhyt5OMK0TfmBK",
  "password": "Oi8AlONgPGlzuR35IwLC6x2NzBdX88qs"
}

mh_topic = "newsData"

mh_producer = create_messagehub_producer( mh_credentials)

import time

print(mh_topic)
data = read_dataset(dataset + ".gz")
for i, entry in enumerate(data):
    rc = mh_producer.send( mh_topic, { 'text': entry } )
    if ((i+1) % 1000) == 0:
        print(i+1, end=" ")
        time.sleep(1) # Slow things down during demo

def mh_consumer_rest(credentials):
    import requests
    import json

    consumerInstance = 'instance1'
    consumerGroup = 'group1'

    authToken = credentials['api_key']
    kafkaRestUrl = credentials['kafka_rest_url']


    headers = {'X-Auth-Token': authToken, 'Content-Type': 'application/vnd.kafka.v1+json'}
    body1 = json.dumps({
    'name': consumerInstance,
    'format': 'binary',
    'auto.offset.reset': 'smallest'
    })
    
    response = requests.post(kafkaRestUrl + "/consumers/" + consumerGroup, data=body1, headers=headers)

    print(response.status_code, response.reason, response.text)
    result = response.json()
    print(result)
    consumerUrl = result['base_uri']
    print(consumerUrl)
    
    return consumerUrl
    
def save_to_cos( cred, bucket_name, object_name, data):
    import requests

    default_iam_url = 'https://iam.ng.bluemix.net/oidc/token'
    default_endpoint = 'https://s3-api.us-geo.objectstorage.service.networklayer.com'
    # Check for credentials or arguments. A StopIteration error means that a valid key was not found.
    api_key = next((n for n in [cred.get('apikey'), cred.get('api_key'), cred.get('IBM_API_KEY_ID')] if n is not None))
    iam_url = next((n for n in [cred.get('iam_url'), cred.get('IBM_AUTH_ENDPOINT')] if n is not None), default_iam_url)
    endpoint = next((n for n in [cred.get('url'), cred.get('ENDPOINT')] if n is not None), default_endpoint)
    
    full_object_path = bucket_name + "/" + object_name
    print("Saving", full_object_path, "(", str(len(data)), "bytes)")

    response = requests.post(
                url = iam_url,
                headers = {"Content-Type": "application/x-www-form-urlencoded"},
                params = {"grant_type":"urn:ibm:params:oauth:grant-type:apikey","apikey":api_key},
                verify = True)
    if str(response) != "<Response [200]>":
        print( "ERROR: POST Response =", response)
        return

mh_credentials = {
  "instance_id": "b32d208f-fbdb-425c-95d3-5b00b56209c4",
  "mqlight_lookup_url": "https://mqlight-lookup-prod02.messagehub.services.us-south.bluemix.net/Lookup?serviceId=b32d208f-fbdb-425c-95d3-5b00b56209c4",
  "api_key": "u4cbPZKOoOHI9uZ5J66JaZBtOF2cRVPYu4UEAG7PXIn4SleB",
  "kafka_admin_url": "https://kafka-admin-prod02.messagehub.services.us-south.bluemix.net:443",
  "kafka_rest_url": "https://kafka-rest-prod02.messagehub.services.us-south.bluemix.net:443",
  "kafka_brokers_sasl": [
    "kafka01-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka03-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka04-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka02-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka05-prod02.messagehub.services.us-south.bluemix.net:9093"
  ],
  "user": "u4cbPZKOoOHI9uZ5",
  "password": "J66JaZBtOF2cRVPYu4UEAG7PXIn4SleB"
}

mh_topic = "newsData"

def send_to_mh(cred, kafkaTopic, data): #value_serializer=lambda v: json.dumps(v).encode('utf-8')):
    import requests
    import json
#    import binascii

    kafka_rest_url = cred.get('kafka_rest_url', 'https://kafka-rest-prod02.messagehub.services.us-south.bluemix.net:443')
    #formatted_data = json.dumps({'records': [{'value':binascii.hexlify(b"some text").decode('utf-8')}]}, ensure_ascii=False).encode('utf8')
    #formatted_data = json.dumps({'records': [{'value':binascii.hexlify(json.dumps(data).encode('utf8')).decode('utf-8')}]}, ensure_ascii=False).encode('utf8')
    formatted_data = json.dumps({'records': [{'value': json.dumps(data).encode('utf8').decode('utf8')}]}, ensure_ascii=False).encode('utf8')

#    print(formatted_data)

    response = requests.post(url = kafka_rest_url + "/topics/" + kafkaTopic,
                             headers = {'X-Auth-Token': cred['api_key'], 'Content-Type': 'application/vnd.kafka.v1+json'},
                             data = formatted_data)

    if response.status_code != 200:
        print( "ERROR: POST Response =", response.status_code, response.reason, response.text)
        return

    return response

import json

#d = json.dumps({'records': [{'value':binascii.hexlify(b"some text").decode('utf-8')}]}, ensure_ascii=False).encode('utf8')
d = {'text': 'some more text'}
print(d)
send_to_mh(mh_credentials, mh_topic, d)

import time

data = read_dataset(dataset + ".gz")
for i, entry in enumerate(data[:5000]):
    send_to_mh(mh_credentials, mh_topic, { 'text': entry } )
    if ((i+1) % 1000) == 0:
        print(i+1, end=" ")
        time.sleep(1) # Slow things down during demo

def send_records_to_mh(cred, kafkaTopic, records): #value_serializer=lambda v: json.dumps(v).encode('utf-8')):
    import requests
    import json

    kafka_rest_url = cred.get('kafka_rest_url', 'https://kafka-rest-prod02.messagehub.services.us-south.bluemix.net:443')
    formatted_data = json.dumps({'records': records}, ensure_ascii=False).encode('utf8')

    response = requests.post(url = kafka_rest_url + "/topics/" + kafkaTopic,
                             headers = {'X-Auth-Token': cred['api_key'], 'Content-Type': 'application/vnd.kafka.v1+json'},
                             data = formatted_data)

    if response.status_code != 200:
        print( "ERROR: POST Response =", response.status_code, response.reason, response.text)
        return

    return response

import time
import json

data = read_dataset(dataset + ".gz")
records = []
for i, entry in enumerate(data[:5000]):
    records.append({'value': json.dumps({'text': entry}).encode('utf8').decode('utf8')})
#    send_to_mh(mh_credentials, mh_topic, { 'text': entry } )
    if ((i+1) % 1000) == 0:
        print(i+1, end=" ")
        send_records_to_mh(mh_credentials, mh_topic, records )
        records = []
        time.sleep(1) # Slow things down during demo

# %%
import ibmos2spark

# @hidden_cell
credentials = {
    'endpoint': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'api_key': 'KFwmHTp1Qbyhr8p3FPUK8tfzw2DouD6X9IFYAxhqUvD9',
    'service_id': 'iam-ServiceId-9a91f062-3319-4553-ae5d-7e80afa896ad',
    'iam_service_endpoint': 'https://iam.ng.bluemix.net/oidc/token'}
credentials = {
    'endpoint': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'api_key': '0s-JWmaDBwiSd_yWJqenoKRBfTVU5Rgkz31CDT5WgoWQ',
    'service_id': '22e3b946-6154-4032-8e8f-7cfb0b429602',
    'iam_service_endpoint': 'https://iam.ng.bluemix.net/oidc/token'}

configuration_name = 'os_22e3b946615440328e8f7cfb0b429602_configs'
cos = ibmos2spark.CloudObjectStorage(sc, credentials, configuration_name, 'bluemix_cos')

from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

#from pyspark.sql import SparkSession
#spark = SparkSession.builder.getOrCreate()

# Please read the documentation of PySpark to learn more about the possibilities to load data files.
# PySpark documentation: https://spark.apache.org/docs/2.0.1/api/python/pyspark.sql.html#pyspark.sql.SparkSession
# The SparkSession object is already initialized for you.
# The following variable contains the path to your file on your IBM Cloud Object Storage.
#####path_1 = cos.url('test.txt', 'streams71aa690a314849ce9b242fd1022a028e')
####print(path_1)

#path_1 = cos.url('click_event_type=add_to_cart/product_category=Beauty Products', 'click')
#path_1 = cos.url('click_event_type=add_to_cart', 'click')
#path_1 = cos.url('CLICKAGG', 'click')
path_1 = cos.url('', 'test04')
print(path_1)

example1_df = sqlContext.read.parquet(path_1)
#print(example1_df.printSchema())
example1_df.take(2)
# Out:
# cos://test04.os_22e3b946615440328e8f7cfb0b429602_configs/\*
# Py4JJavaErrorTraceback (most recent call last)
# <ipython-input-17-d5f2d14c1923> in <module>()
#      35 print(path_1)
#      36
# ---> 37 example1_df = sqlContext.read.parquet(path_1)
#      38 #print(example1_df.printSchema())
#      39 example1_df.take(2)
#
# /usr/local/src/spark21master/spark/python/pyspark/sql/readwriter.py in parquet(self, *paths)
#     272         [('name', 'string'), ('year', 'int'), ('month', 'int'), ('day', 'int')]
#     273         """
# --> 274         return self._df(self._jreader.parquet(_to_seq(self._spark._sc, paths)))
#     275
#     276     @ignore_unicode_prefix
#
# /usr/local/src/spark21master/spark/python/lib/py4j-0.10.4-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
# -> 1133             answer, self.gateway_client, self.target_id, self.name)
#    1134
# ...

# %%
example1_df.distinct().count()
# Out:
# 564

# %%
example1_df.count()
# Out:
# 5449

# %%
mh_credentials = {
  "instance_id": "b32d208f-fbdb-425c-95d3-5b00b56209c4",
  "mqlight_lookup_url": "https://mqlight-lookup-prod02.messagehub.services.us-south.bluemix.net/Lookup?serviceId=b32d208f-fbdb-425c-95d3-5b00b56209c4",
  "api_key": "u4cbPZKOoOHI9uZ5J66JaZBtOF2cRVPYu4UEAG7PXIn4SleB",
  "kafka_admin_url": "https://kafka-admin-prod02.messagehub.services.us-south.bluemix.net:443",
  "kafka_rest_url": "https://kafka-rest-prod02.messagehub.services.us-south.bluemix.net:443",
  "kafka_brokers_sasl": [
    "kafka01-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka03-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka04-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka02-prod02.messagehub.services.us-south.bluemix.net:9093",
    "kafka05-prod02.messagehub.services.us-south.bluemix.net:9093"
  ],
  "user": "u4cbPZKOoOHI9uZ5",
  "password": "J66JaZBtOF2cRVPYu4UEAG7PXIn4SleB"
}
mh_topic = "newsData"

def mh_consumer_rest(credentials):
    import requests
    import json

    consumerInstance = 'instance1'
    consumerGroup = 'group1'

    authToken = credentials['api_key']
    kafkaRestUrl = credentials['kafka_rest_url']


    headers = {'X-Auth-Token': authToken, 'Content-Type': 'application/vnd.kafka.v1+json'}
    body1 = json.dumps({
    'name': consumerInstance,
    'format': 'binary',
    'auto.offset.reset': 'smallest'
    })
    
    response = requests.post(kafkaRestUrl + "/consumers/" + consumerGroup, data=body1, headers=headers)

    print(response.status_code, response.reason, response.text)
    result = response.json()
    print(result)
    consumerUrl = result['base_uri']
    print(consumerUrl)
    
    return consumerUrl

mh_consumer_rest(mh_credentials)
